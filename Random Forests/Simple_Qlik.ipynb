# %%
import pandas as pd 
import numpy as np

# %%
cbs_data = pd.read_excel("D:\Membership Declaration_Dec 2025.xlsx")

# %%
qlik_data = pd.read_excel("D:\Untitled - Table - January 12, 2026.xlsx")
# Out:
#   Cell In[26], line 1
#     qlik_data = pd.read_excel("D:\Untitled - Table - January 12, 2026.xlsx")
#                                                                            ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
cbs_data.head(10)
# Out:
#     BBF Code                Name  Member No ID No Date Of Birth Gender   \
# 0  PRINCIPLE   PAUL MABWA NDAKALA   0000003     0   1 July 1940    Male
# 1      CHILD       LILIAN M MUTIE       NaN     1           NaN
# 2      CHILD      PURITY M MUTIE        NaN     2           NaN
# 3      CHILD     GENESIS K MUTIE        NaN     3           NaN
# 4      CHILD         VIOLA MUTIE        NaN     4           NaN
# 5     PARENT   RUTH SANGULI NDETO       NaN     5           NaN
# 6      CHILD       GENESIS MUTIE        NaN     6           NaN
# 7     SPOUSE        HURRIET MUTIE       NaN     7           NaN
# 8  PRINCIPLE      Mr JACKTON KOLA   0000010   NaN           NaN
# 9        NaN                  NaN       NaN   NaN           NaN     NaN
#
#   Status Members  Unnamed: 7
# 0      Defaulter           7
# 1            NaN           3
# 2            NaN           3
# 3            NaN           3
# 4            NaN           3
# 5            NaN           3
# ...
